# %% [markdown]
# # 3 Qubit Error Correction Code using Parameterized Quantum Circuit Using Batch Optimization
#
# We implemented a Parameterized Quantum Circuit for 3 Qubits. We added bit-flip noise to the model. Later, we optimized the parameters of the circuit iteratively in order to reduce the error.
#
# Explanation: At the start, 3 Qubits are initialized. q0, q1 and q2
# are ancilla bits. A random state is generated as an Input
# State. This random state, $|\psi>$ is assigned to the second
# qubit, q1. We are adding noise to our circuit in order to
# bit flip one qubit. Our aim is retrieving the original input
# state even after noise is added to the model by optimizing the parameters iteratively. Therefore,
# our target state |$\hat{\psi}$> is equivalent to our input state |$\psi$>.

# %%
import numpy as np
import math
np.random.seed(20)

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute, Aer
from qiskit.extensions import Initialize

# %% [markdown]
# ## One Qubit Unitary Circuit

# %%
def one_qubit_unitary(params, q1):
    cir = QuantumCircuit(3, 3, name = '1 Qubit Unitaryn')
    
    cir.rx(params[0], q1)
    cir.ry(params[1], q1)
    cir.rz(params[2], q1)
    
    return cir

params = np.arange(0, 3)
one_qubit_unitary(params, 1).draw(output='mpl')

# %% [markdown]
# ## Two Qubit Rotation Circuit

# %%
def two_qubit_rotation(params, q1, q2):
    cir = QuantumCircuit(3, 3, name = '2 Qubit Rotation')
    
    cir += one_qubit_unitary(params[0: 3], q1)
    cir += one_qubit_unitary(params[3 : 6], q2)
    
    return cir

params = np.arange(0, 6)
two_qubit_rotation(params, 0, 2).draw(output='mpl')

# %% [markdown]
# ## Two Qubit Unitary Circuit

# %%
def two_qubit_unitary(params, q1, q2):
    cir = QuantumCircuit(3, 3, name = 'Two Qubit Unitary')
    
    cir += two_qubit_rotation(params[0 : 6], q1, q2)
    cir.rzz(params[6], q1, q2)
    cir.ryy(params[7], q1, q2)
    cir.rxx(params[8], q1, q2)
    cir += two_qubit_rotation(params[9 : 15], q1, q2)
    cir.barrier()
    
    
    return cir

# visualizing Two Qubit Unitary to check
params = np.arange(0, 15)
two_qubit_unitary(params, 0, 1).draw(output='mpl')

# %% [markdown]
# # Building Blocks of The Parametric Circuit

# %% [markdown]
# ## Pooling Circuit

# %%
def pooling(params, q1, q2):
    cir = QuantumCircuit(3, 3, name = 'Pooling')
    unitary = one_qubit_unitary(params[0: 3], q2)
    cir += unitary
    cir += one_qubit_unitary(params[3: 6], q1)
    cir.cx(q1, q2)
    cir += unitary.inverse()
    
    return cir

params = np.arange(0, 6)
pooling(params, 0, 1).draw(output='mpl')

# %% [markdown]
# ## Decoder Circuit

# %%
# Defining Decoder circuit. Decoder is inversion of Encoder.
def decoder(params):
    dec = QuantumCircuit(3, 3, name = 'Decoder')
    dec += two_qubit_unitary(params[0 : 15], 0, 1)
    dec += two_qubit_unitary(params[0 : 15], 1, 2)
    dec += two_qubit_unitary(params[0 : 15], 2, 0)
    
    dec += pooling(params[15 : 21], 0, 1)
    dec.barrier()
    dec += pooling(params[15 : 21], 2, 1)
    return dec

# visualizing Decoder to check
params = np.arange(0, 21)
decoder(params).draw(output='mpl')

# %% [markdown]
# ## Encoder Circuit

# %%
# Defining Encoder circuit. Parameters and input state is given as arguments.
def encoder(decoder):
    enc = QuantumCircuit(3, 3, name = 'Encoder')
    enc = decoder.inverse()
    
    return enc

# visualizing Encoder to check
params = np.arange(0, 21)
encoder(decoder(params)).draw(output='mpl')

# %% [markdown]
# ## Correction Circuit

# %%
# def correction(params):
#     qc = QuantumCircuit(3, 1, name = 'Correction')
#     for i in range(1, 5):
#         qc.u3(params[55+(i-1)*6], params[56+(i-1)*6], params[57+(i-1)*6], 1)
#         qc.u3(params[58+(i-1)*6], params[ 59+(i-1)*6], params[60+(i-1)*6], 2)
        
#         if(i != 4):
#             qc.cx(1,2)
        
#     qc.barrier()
        
#     for i in range(1, 5):
#         qc.u3(params[79+(i-1)*6], params[80+(i-1)*6], params[81+(i-1)*6],0)
#         qc.u3(params[82+(i-1)*6], params[83+(i-1)*6], params[84+(i-1)*6],1)
        
#         if(i != 4):
#             qc.cx(1,0)
#     return qc
# params = np.arange(0,103)
# correction(params).draw(output='mpl', cregbundle = False)

# %% [markdown]
# ## Complete Circuit

# %%
def get_var_form(params, q1_state, error_qubit):
    # Adding input state
    qc = QuantumCircuit(3, 3)
    qc.append(q1_state, [1])
    qc.barrier()

    # Creating encoder circuit
#     enc = encoder(params)
#     # Appending encoder sub-circuit to the main qc. (alternate to qc += enc)
#     qc.append(enc.to_instruction(), enc.qubits)
#     qc.barrier()
    
    dec = decoder(params)
    enc = encoder(dec)
    qc += enc
    
    qc.barrier()
    
    #Adding error to Quantum Circuit
#     error_decision = np.random.choice([0, 1], p=[0, 1])
#     if(error_decision == 1):
#         error_qubit = np.random.randint(3)
    if(error_qubit != -1):
        qc.x(error_qubit)
        qc.barrier()

    # Creating encoder circuit
#     dec = decoder(enc)
#     # Appending decoder sub-circuit to the main qc. (alternate to qc += dec)
#     qc.append(dec.to_instruction(), dec.qubits)

    qc += dec
    
#     corr = correction(params)
#     qc += corr
#     qc.ccx(0, 2, 1)

    
    
    qc.barrier()
    
    # Measuring ancilla qubits
 #   qc.measure([0, 2], [0, 1])

#     qc.cx(1,0)
#     qc.cx(1,2)
#     qc.barrier()
    
#     if(error_qubit != -1):
#         qc.x(error_qubit)
#         qc.barrier()
        
#     qc.cx(1,0)
#     qc.cx(1,2)
    qc.ccx(0,2,1)
    qc.barrier()
        
    qc.measure([0, 2], [0, 0])   
    
    return qc


# visualizing complete circuit to check
params = np.arange(0, 21)
initial_state = [0, 1]
q1_state = Initialize(initial_state)
get_var_form(params, q1_state, 1).draw(output='mpl')

# %% [markdown]
# ## Generalized Output State

# %%
def gen_states(output_state, target_state):
    alpha = math.sqrt((abs(output_state[0]) ** 2) + (abs(output_state[1]) ** 2) + (abs(output_state[4]) ** 2) + (abs(output_state[5]) ** 2))
    beta = None
    
    if alpha == 0:
        beta = math.sqrt((abs(output_state[2]) ** 2) + (abs(output_state[3]) ** 2) + (abs(output_state[6]) ** 2) + (abs(output_state[7]) ** 2))
    else:
        beta = ( (output_state[2] + output_state[3] + output_state[6] + output_state[7]) / (output_state[0] + output_state[1] + output_state[4] + output_state[5]) ) * alpha
    
    a, b = target_state[0], target_state[1]
    if abs(a) == 0:
        b = abs(b)
    else:
        b = (b / a) * abs(a)
    a = abs(a)
    
    return np.array([alpha, beta]), np.array([a, b])

# %% [markdown]
# ## Configuring Simulator

# %%
# Import Aer
from qiskit import Aer, execute

# Run the quantum circuit on a statevector simulator backend
backend = Aer.get_backend('statevector_simulator')

# %% [markdown]
# ## Creating Cost Function

# %%
def objective_function(params):
    cost = 0
    
    for q1_state in input_states:
        target_state = q1_state
        # initializing state
        q1_state = Initialize(q1_state)
        
        for error_qubit in range(-1, 3):
            # Obtain a quantum circuit instance from the paramters
            qc = get_var_form(params, q1_state, error_qubit)
            # Execute the quantum circuit to obtain the probability distribution associated with the current parameters
            result = execute(qc, backend).result()
            output_state = result.get_statevector(qc)
            output_state = np.array(output_state)
            output_state, target_state = gen_states(output_state, target_state)
            # adding cost for single circuit
            cost += np.linalg.norm(output_state - target_state)
        
    # returning total cost
    return cost

# %% [markdown]
# ## Running optimizer

# %%
from qiskit.aqua.components import optimizers

# for timing the optimization sessions 
import time

# %%
# Function to create batch according to batch size
def create_batch(batch_size):
    # Function to return an array after normalizing the elements
    def normalize(arr):
        return arr / np.linalg.norm(arr)
    # Generating random_states
    random_states = np.random.rand(batch_size * 2) + np.random.rand(batch_size * 2)*1j
    # Creating normalized input states from random states and appending to an array
    input_states = np.array([normalize([random_states[i], random_states[i + 1]]) for i in range(0, 2 * batch_size, 2)])
    # Creating target states corresponding to the input states
#     target_states = [[input_states[i][0], 0, input_states[i][1], 0, 0, 0, 0, 0] for i in range (batch_size)]

    return input_states

# %%
def optimize_circuit(initial_params, iteration, num_epoch, batch_size):
    current_params = initial_params
    current_error = None
    data = []
    
    # Defining global variables
    global input_states
    global target_states
    global results
    
    input_states = create_batch(batch_size)

    # Initialize the optimizer
    optimizer = optimizers.COBYLA(maxiter = iteration)
    
    # Running batch optimization epoch by epoch
    for i in range (0, num_epoch):
        iter_start = time.time()
        # run optimizer
        ret = optimizer.optimize(num_vars=len(initial_params), 
                                 objective_function=objective_function, initial_point=current_params)
        
        current_params = ret[0]
        current_error = ret[1]
        
        print("Finished Epoch: " + str(i+1) + " ..... " + "Iteration: " + str(iteration) + " ..... " + "Current Error: " + str(current_error) + " ..... " + " Time running: " + str(time.time() - iter_start) + " seconds")
        
        # Simulation result for all circuits will be stored in this list
        data.append(current_error)
    
    # A list to contain each number of epoch
    epoch_list = np.arange(1, (num_epoch + 1))
    # Adding errror and corresponding circuit number to a list
    results = [data, epoch_list]
    
    # returning final optimized parameters and error
    return current_params, current_error

# %% [markdown]
# ## Initializing Parameters

# %%
from math import pi
initial_params = np.random.uniform(0, 2*math.pi, 21)
# initial_params = np.array([math.pi, 0, math.pi, math.pi, 0, math.pi])
print("Initial Parameters:")
print(initial_params)
# Out:
# Initial Parameters:
# [3.69533481 5.64050171 5.60165278 5.12605805 0.22550092 4.34644107
#  2.37932253 3.25790035 4.13403098 1.21799684 1.71101442 4.51513424
#  4.91975677 5.34276613 4.87100733 0.23036863 0.73320836 4.72043585
#  1.50305238 1.6009934  5.38862014]

# %%
results = []


# Hyperparameters: number of iteration, number of epochs and batch size
iteration = 200
num_epoch = 50
batch_size = 100

# Optimizing and printing the results
iter_start = time.time()
optimized_params, error = optimize_circuit(initial_params, iteration, num_epoch, batch_size)

print(iteration,"Iterations..... 103 parameters optimized.....", (time.time() - iter_start), "seconds for running")
print()
print("Error:")
print(error)
print()
print("Optimized Parameters:")
print(optimized_params)
# Out:
# Finished Epoch: 1 ..... Iteration: 200 ..... Current Error: 133.95679452230434 .....  Time running: 2644.1211788654327 seconds
# Finished Epoch: 2 ..... Iteration: 200 ..... Current Error: 96.552846327543 .....  Time running: 3048.7982561588287 seconds
# Finished Epoch: 3 ..... Iteration: 200 ..... Current Error: 102.65561872444765 .....  Time running: 2122.9345009326935 seconds
# Finished Epoch: 4 ..... Iteration: 200 ..... Current Error: 97.15899013624941 .....  Time running: 2427.5381989479065 seconds
# Finished Epoch: 5 ..... Iteration: 200 ..... Current Error: 95.51090957293447 .....  Time running: 2709.951352596283 seconds
# Finished Epoch: 6 ..... Iteration: 200 ..... Current Error: 83.81232262248405 .....  Time running: 3109.292744874954 seconds
# Finished Epoch: 7 ..... Iteration: 200 ..... Current Error: 86.91466517695896 .....  Time running: 2981.978070497513 seconds
# Finished Epoch: 8 ..... Iteration: 200 ..... Current Error: 86.91924929902531 .....  Time running: 2791.4724159240723 seconds
# Finished Epoch: 9 ..... Iteration: 200 ..... Current Error: 86.50263589558638 .....  Time running: 2403.581736087799 seconds
# Finished Epoch: 10 ..... Iteration: 200 ..... Current Error: 90.12744920769771 .....  Time running: 1971.8969492912292 seconds
# Finished Epoch: 11 ..... Iteration: 200 ..... Current Error: 87.28242391581935 .....  Time running: 2133.235716342926 seconds
# Finished Epoch: 12 ..... Iteration: 200 ..... Current Error: 85.45230166448094 .....  Time running: 2108.2865793704987 seconds
# Finished Epoch: 13 ..... Iteration: 200 ..... Current Error: 90.10479599258454 .....  Time running: 2520.8518867492676 seconds
# Finished Epoch: 14 ..... Iteration: 200 ..... Current Error: 90.65197479681439 .....  Time running: 2462.9498579502106 seconds
# Finished Epoch: 15 ..... Iteration: 200 ..... Current Error: 100.20696220942628 .....  Time running: 2565.3827843666077 seconds
# Finished Epoch: 16 ..... Iteration: 200 ..... Current Error: 78.85505935364093 .....  Time running: 2689.417638063431 seconds
# Finished Epoch: 17 ..... Iteration: 200 ..... Current Error: 85.86616808450505 .....  Time running: 2100.5846977233887 seconds
# Finished Epoch: 18 ..... Iteration: 200 ..... Current Error: 77.95649817327693 .....  Time running: 2081.406154155731 seconds
# Finished Epoch: 19 ..... Iteration: 200 ..... Current Error: 77.57158519688107 .....  Time running: 2104.3212308883667 seconds
# Finished Epoch: 20 ..... Iteration: 200 ..... Current Error: 78.91176471432945 .....  Time running: 2411.543050289154 seconds
# Finished Epoch: 21 ..... Iteration: 200 ..... Current Error: 74.78619807044345 .....  Time running: 2662.4708478450775 seconds
# Finished Epoch: 22 ..... Iteration: 200 ..... Current Error: 77.12129471336831 .....  Time running: 2615.2530858516693 seconds
# Finished Epoch: 23 ..... Iteration: 200 ..... Current Error: 76.84605458692648 .....  Time running: 2584.2341873645782 seconds
# Finished Epoch: 24 ..... Iteration: 200 ..... Current Error: 74.01145821631988 .....  Time running: 2739.3042788505554 seconds
# Finished Epoch: 25 ..... Iteration: 200 ..... Current Error: 76.48848945123248 .....  Time running: 2675.798951625824 seconds
# Finished Epoch: 26 ..... Iteration: 200 ..... Current Error: 72.79662391839473 .....  Time running: 3131.7260529994965 seconds
# Finished Epoch: 27 ..... Iteration: 200 ..... Current Error: 75.57532998732248 .....  Time running: 2428.9335536956787 seconds
# Finished Epoch: 28 ..... Iteration: 200 ..... Current Error: 74.67864004069827 .....  Time running: 2912.030244588852 seconds
# Finished Epoch: 29 ..... Iteration: 200 ..... Current Error: 74.09938892664968 .....  Time running: 3074.064484357834 seconds
# Finished Epoch: 30 ..... Iteration: 200 ..... Current Error: 76.30216097018744 .....  Time running: 2982.336920261383 seconds
# Finished Epoch: 31 ..... Iteration: 200 ..... Current Error: 73.24467245827513 .....  Time running: 2977.3759076595306 seconds
# Finished Epoch: 32 ..... Iteration: 200 ..... Current Error: 77.49468421071506 .....  Time running: 2792.7371542453766 seconds
# Finished Epoch: 33 ..... Iteration: 200 ..... Current Error: 78.48710555883676 .....  Time running: 2425.3547534942627 seconds
# Finished Epoch: 34 ..... Iteration: 200 ..... Current Error: 78.26330633306786 .....  Time running: 2527.8660609722137 seconds
# Finished Epoch: 35 ..... Iteration: 200 ..... Current Error: 76.01411746433214 .....  Time running: 1220.6871201992035 seconds
# Finished Epoch: 36 ..... Iteration: 200 ..... Current Error: 77.10242186532095 .....  Time running: 1171.7097327709198 seconds
# Finished Epoch: 37 ..... Iteration: 200 ..... Current Error: 77.79382495190512 .....  Time running: 1290.0112447738647 seconds
# Finished Epoch: 38 ..... Iteration: 200 ..... Current Error: 77.0914076930803 .....  Time running: 1247.681092262268 seconds
# Finished Epoch: 39 ..... Iteration: 200 ..... Current Error: 73.82377523530684 .....  Time running: 1578.365453004837 seconds
# Finished Epoch: 40 ..... Iteration: 200 ..... Current Error: 76.13854423086521 .....  Time running: 1711.0811431407928 seconds
# Finished Epoch: 41 ..... Iteration: 200 ..... Current Error: 79.8672136675071 .....  Time running: 1640.7233278751373 seconds
# Finished Epoch: 42 ..... Iteration: 200 ..... Current Error: 83.48303166874393 .....  Time running: 1510.5586733818054 seconds
# Finished Epoch: 43 ..... Iteration: 200 ..... Current Error: 80.24734225522272 .....  Time running: 1569.9347760677338 seconds
# Finished Epoch: 44 ..... Iteration: 200 ..... Current Error: 79.86717921489709 .....  Time running: 1391.9366071224213 seconds
# Finished Epoch: 45 ..... Iteration: 200 ..... Current Error: 75.03262151835125 .....  Time running: 1314.1758079528809 seconds
# Finished Epoch: 46 ..... Iteration: 200 ..... Current Error: 76.99234594723745 .....  Time running: 1322.6743664741516 seconds
# Finished Epoch: 47 ..... Iteration: 200 ..... Current Error: 75.16625734986256 .....  Time running: 1271.9701116085052 seconds
# Finished Epoch: 48 ..... Iteration: 200 ..... Current Error: 76.00515823305291 .....  Time running: 1312.5111446380615 seconds
# Finished Epoch: 49 ..... Iteration: 200 ..... Current Error: 75.6424364408349 .....  Time running: 1437.1490731239319 seconds
# Finished Epoch: 50 ..... Iteration: 200 ..... Current Error: 82.00630942318129 .....  Time running: 1587.6313829421997 seconds
# 200 Iterations..... 103 parameters optimized..... 110497.8505589962 seconds for running
#
# Error:
# 82.00630942318129
#
# Optimized Parameters:
# [ 2.50259373  5.98131522  6.2734949   5.27677564 -0.03620338  4.60247523
#   1.40275869  3.01455999  4.73735972  2.58359883  1.85697105  4.3859058
#   5.24269199  5.99276739  6.55845011 20.01937738  9.71257129 11.40112777
#   3.83513639  1.23472277 17.6226747 ]

# %% [markdown]
# # Plot Results for Comparison

# %%
import matplotlib.pyplot as plt
COLOR = '#4a87e0'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# function to plot results for comparison 
def plot_result(results):

    plt.plot(results[1], results[0], label=iteration, marker='o', ls='-')

    plt.xlabel('Epoch Number')
    plt.ylabel('Error')

    plt.title('Evolution of Error with Number of Epochs')

    plt.legend(loc="lower right", bbox_to_anchor=(1.2, 0), title='no. of \n optimizer\n iterations')
    plt.show()

plot_result(results)
